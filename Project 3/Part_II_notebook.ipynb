# %% [markdown]
# # Part II - Prosper Loan Dataset Explanatory Analysis
# ### by MAAROUFI Sirine

# %% [markdown]
# ## Investigation Overview
#
#
# > The goal of this presentation is to present the following key insights found in Part I of this project:
# > * The amount of money requested by borrowers is influenced by BorrowerRate and ProsperRate.
# > * ProsperRating is highly dependent on LoanOriginalAmount.
# > * LoanOriginalAmount is dependent on EmploymentStatus.
#
#
# ## Dataset Overview
#
# > The dataset we're going to use in this project is Loan Data from Prosper. This data set contains 113,937 loans with 81 variables on each loan, including loan amount, borrower rate (or interest rate), current loan status, borrower income, and many others.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
loan_data = pd.read_csv('prosperLoanData.csv')

# %%
# Data Cleaning
loan_data_clean = loan_data.copy()

# Drop columns with more than half of their values are missing
loan_data_clean.dropna(axis = 'columns', thresh = 113937*0.5, inplace= True)
# Drop rows with more than half of their values are missing
loan_data_clean.dropna(axis = 'rows', inplace= True)
# Correct Datatypes
loan_data_clean['ListingCreationDate'] = loan_data_clean['ListingCreationDate'].astype('datetime64[ns]')
loan_data_clean['LoanOriginationDate'] = loan_data_clean['LoanOriginationDate'].astype('datetime64[ns]')
loan_data_clean['DateCreditPulled'] = loan_data_clean['DateCreditPulled'].astype('datetime64[ns]')
loan_data_clean['FirstRecordedCreditLine'] = loan_data_clean['FirstRecordedCreditLine'].astype('datetime64[ns]')

# %% [markdown]
# ## LoanOriginalAmount By Prosper Rating
#
# > This plot shows how the Prosper Rating is dependent on The amount of money requested from borrowers.

# %%
plt.figure(figsize = [8, 6])
x = loan_data_clean['ProsperRating (numeric)']
y = loan_data_clean['LoanOriginalAmount']
plt.bar(x,y);
plt.xlabel('ProsperRating (numeric)')
plt.ylabel('LoanOriginalAmount')
plt.title('LoanOriginalAmount By Prosper Rating ')
plt.show()

# %% [markdown]
# ## LoanOriginalAmount By EmploymentStatus.
#
# > This plot shows how the amount of money requested is dependent on Employment Status of the borrower.

# %%
plt.figure(figsize = [8, 6])
y = loan_data_clean['LoanOriginalAmount']
x = loan_data_clean['EmploymentStatus']
plt.bar(x,y);
plt.ylabel('Loan Original Amount ($)')
plt.xlabel('Employment Status')
plt.title('LoanOriginalAmount by EmploymentStatus')
plt.show()

# %% [markdown]
# ## LoanOriginalAmount by BorrowerRate and ProsperRating
#
# > This plot shows how the amount of money requested by borrowers is influenced by BorrowerRate and ProsperRate.
#
# > We can conlude that Borrowers who have good prosper rating have an opportunity to avail lower borrower rates and at the same time, they can take higher loans.

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams["figure.figsize"] = [14.00, 8.00]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = Axes3D(fig)
x = loan_data_clean['ProsperRating (numeric)']
y = loan_data_clean.BorrowerRate
z = loan_data_clean.LoanOriginalAmount
ax.scatter3D(x, y, z, c=z, alpha=1, marker='.', s=150);
plt.xlabel('ProsperRating (numeric)')
plt.ylabel('BorrowerRate')
ax.set_zlabel('LoanOriginalAmount')
plt.title('LoanOriginalAmount by BorrowerRate and ProsperRating')
plt.legend()
plt.show();

# %%
# Use this command if you are running this file in local
# !jupyter nbconvert Part_II_notebook.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_notebook.ipynb to slides
# [NbConvertApp] Writing 571262 bytes to Part_II_notebook.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Part_II_notebook.slides.html
# Use Control-C to stop this server
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: x-www-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: firefox: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: iceweasel: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: seamonkey: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: mozilla: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: epiphany: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: konqueror: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: chromium-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: google-chrome: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'http://127.0.0.1:8000/Part_II_notebook.slides.html'
